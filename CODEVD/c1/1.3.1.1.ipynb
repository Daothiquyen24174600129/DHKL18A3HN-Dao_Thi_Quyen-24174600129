# %%
class Dog:  
    # Minh họa lớp Dog với các thuộc tính protected
    _DogCount = 0

    def __init__(self, name: str, size: str, age: int):
        self._name = name        
        Dog._DogCount += 1

    def _displayInfo(self):  
        print(f"Name is a {self._name}") 
d = Dog("Bull", "large", 2)
d.display() 
# phá hoại quy ước
print(f"tên chó là: {d._name}")
