# %%
class Dog:  
    __DogCount = 0

    def __init__(self, name: str, size: str, age: int):
        self.__name = name
        self.__age = age
        Dog.__DogCount += 1

    def __display(self):
        print(f"Name: {self.__name}, Age: {self.__age}")
    
    def get_name(self):
        return self.__name
dog1 = Dog("Bull", "Large", 1)

print("Name is a", dog1.get_name())
print("Number of dogs:", Dog._Dog__DogCount)
