# %%
class Dog:
    __DogCount = 0   

    def __init__(self, name, size, age, color):
        self._name = name       
        self._size = size       
        self.__age = age      
        self.color = color      
        Dog.__DogCount += 1     

obj1 = Dog("bull", "large", 2, "yellow")

d = Dog("Du11*, *lange", 2)
print (d.nane)
d.display()
