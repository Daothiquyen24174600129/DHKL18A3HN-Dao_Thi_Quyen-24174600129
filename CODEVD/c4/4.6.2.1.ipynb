# %%
import numpy as pd
df = pd.DataFrame

# %%
idx_tuples=[('a',1),('a',2),('b',1),('b',2)]

# %%
arr1 = ['a','b']
arr2 =[1, 2, 3]
multi_idx = pd.MultiIndex.from_produc([arr1,arr2],
                                      names=['key1','key2'])
df =

# %%
index = pd.MultiIndex.from_product([[2020,2021,2022],[1,2,3]],
                                   names=['Năm','Lân thi'])

# %%
import numpy as np
df= pd.DataFrame(np.random.rand(4,2),
                 index=[['a','a','b','b'],[1,2,1,2]],
                 columns=['data1','data2'])
df
# tạo --- từ MẢNG
idx_arr=[['a','a','b','b'],[1,2,1,2]]
data=np.random.rand(4,3) # tảo mảng ngẫu nhiên
# tạo đtg từ mảng idx_arr
multi_index=pd.MultiIndex.from_arrays(idx_arr,names=['data1','data2'])
# tạo dataframe
df= pd.DataFrame(data,index=multi_index,
                 columns=['value1','value2','value3'])
df
# tạo---- cho cột
index=pd.MultiIndex.from_product([[2020,2021,2022],[1,2,3]],
                                 names=['năm','lần thi'])
columns=pd.MultiIndex.from_product([['bình','lan ','văn'],
                                    ['toán','lý','hoá']],
                                names=['học sinh','môn học'])
data=np.random.randint(5,10,(9,9))
score=pd.DataFrame(data,index=index, columns=columns)
score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 df= pd.DataFrame(np.random.rand(4,2),
#       3                  index=[['a','a','b','b'],[1,2,1,2]],
#       4                  columns=['data1','data2'])
#       5 df
#       6 # tạo --- từ MẢNG
#
# NameError: name 'pd' is not defined
