# %%
import pandas as pd
import numpy as np
sr_auto=pd.Series([1,2, np.nan, 4, None])
sr_auto
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    NaN
# dtype: float64

# %%
print(f"Dtype sau khi cuyen doi: {sr_auto.dtype}")
# Out:
# Dtype sau khi cuyen doi: float64

# %%
sr_int_na = pd.Series([1, 2, None, 4], dtype=pd.Int64Dtype())
print(f"Series giu Int: \n{sr_int_na}")
print(f"Dtype sau:")

# %%
st_sr=pd.Series(['Uneti', 'Khud',None,np.nan])
st_sr
# Out:
# 0    Uneti
# 1     Khud
# 2     None
# 3      NaN
# dtype: object
