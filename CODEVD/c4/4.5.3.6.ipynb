# %%
import numpy as np
import pandas as pd
data = pd.Series([1, np.nan, 2, None,3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data.fillna('khong ro')
# Out:
# a         1.0
# b    khong ro
# c         2.0
# d    khong ro
# e         3.0
# dtype: object
