# %%
import numpy as np
x = np.array([1, 2, 3])
x.reshape((1, 3))
# Out:
# array([[1, 2, 3]])

# %%
x[np.newaxis, :] # tao ma tran 1x3 su dung np.newaxis()
# Out:
# array([[1, 2, 3]])

# %%
np.newaxis is None
# Out:
# True

# %%
y=x[np.newaxis, :]
print(f'ma tran x ban dau: ', x)
print('ma tran y sau khi them hang: ', y)
# Out:
# ma tran x ban dau:  [1 2 3]
# ma tran y sau khi them hang:  [[1 2 3]]

# %%
z=x[:,np.newaxis, :]
print('ma tran x ban dau:', x)
print('ma tran z sau khi them cot:\n', z)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 z=x[:,np.newaxis, :]
#       2 print('ma tran x ban dau:', x)
#       3 print('ma tran z sau khi them cot:\n', z)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
x
# Out:
# array([1, 2, 3])

# %%
x[np.newaxis, :]
# Out:
# array([[1, 2, 3]])

# %%
x.reshape((3, 1))
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
np.ndim(x) # kiem tra so chieu cua mang x sau khi reshape
# Out:
# 1

# %%
np.ndim(x.reshape((3, 1)))
# Out:
# 2
