# %%
import numpy as np 
arr1=np.random.rand(5) 
arr1
# Out:
# array([0.93346702, 0.53939917, 0.34043337, 0.40635131, 0.13800371])

# %%
arr2=np.random.rand(5) 
arr2
# Out:
# array([0.19737069, 0.72318668, 0.64274409, 0.67072403, 0.63892888])

# %%
arr_maximum=np.maximum(arr1,arr2) 
print("Mảng kết quả là:",arr_maximum)
# Out:
# Mảng kết quả là: [0.93346702 0.72318668 0.64274409 0.67072403 0.63892888]
