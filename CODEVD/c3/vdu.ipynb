# %%
import numpy as np
my_list = [1, 2, 3, 4, 5]
arr_1 = np.array(my_list)
print(arr_1)
# Out:
# [1 2 3 4 5]

# %%
arr_1.dtype
# Out:
# dtype('int64')

# %%
arr_2=np.array([my_list], dtype=float)
arr_2
# Out:
# array([[1., 2., 3., 4., 5.]])

# %%
arr_2.dtype
# Out:
# dtype('float64')

# %%
# tao mang tu dnnh sach
my_tuple=(1,2,3,4,5)
arr_3=np.array(my_tuple)
arr_3
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr_3.dtype
# Out:
# dtype('int64')

# %%
#####################Tao numpy array tu mang hai chieu 
arr_4=np.array([(1,2,3),(4,5,6)])
arr_4
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
arr_4.dtype
# Out:
# dtype('int64')
