# %%
import numpy as np
# Lấy tất cả các phần tử nằm tại hàng >= 1 và các cột = 1, 2, 3 tương ứng 
sub_arr = arr[1:, [1, 2, 3]] 
print("Mảng con sub_arr:\n", sub_arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import numpy as np
#       2 # Lấy tất cả các phần tử nằm tại hàng >= 1 và các cột = 1, 2, 3 tương ứng
# ----> 3 sub_arr = arr[1:, [1, 2, 3]]
#       4 print("Mảng con sub_arr:\n", sub_arr)
#
# NameError: name 'arr' is not defined
