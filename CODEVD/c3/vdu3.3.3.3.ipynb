# %%
import numpy as np
sub_arr_copy=arr[2:,:2].copy()
print(sub_arr_copy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 sub_arr_copy=arr[2:,:2].copy()
#       3 print(sub_arr_copy)
#
# NameError: name 'arr' is not defined
