# %%
import numpy as np

# Tạo một mảng mẫu
arr = np.array([10, 25, 60, 75, 40, 90])

# Fancy indexing và boolean indexing
sub_arr_boolean = arr[arr > 50]
print("Original Array:\n", arr)

# Boolean Indexing
print("After Boolean Condition:", arr[arr > 50])
# Out:
# Original Array:
#  [10 25 60 75 40 90]
# After Boolean Condition: [60 75 90]

# %%
#Mảng chỉ mục là mảng 2 chiều 
idx_arr=np.array([[1,2], 
                 [5,6]]) 
sub_arr_2=arr[idx_arr] 
print(sub_arr_2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 #Mảng chỉ mục là mảng 2 chiều
#       2 idx_arr=np.array([[1,2],
#       3                  [5,6]])
# ----> 4 sub_arr_2=arr[idx_arr]
#       5 print(sub_arr_2)
#
# IndexError: index 6 is out of bounds for axis 0 with size 6
